# %% [markdown]
# #### Installations

# %%
#!pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 40.8 MB 29.2 MB/s eta 0:00:01
# ...

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import sklearn

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet')
df.sample(5)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 444462          2  2024-01-06 10:37:40   2024-01-06 10:42:44              1.0
# 1644522         1  2024-01-19 16:55:02   2024-01-19 17:12:12              0.0
# 2592333         1  2024-01-29 16:28:05   2024-01-29 16:42:49              0.0
# 1915662         2  2024-01-22 16:03:18   2024-01-22 16:17:06              1.0
# 2001486         2  2024-01-23 15:03:05   2024-01-23 15:05:46              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 444462            1.27         1.0                  N            48
# 1644522           1.90         1.0                  N           141
# 2592333           2.20         1.0                  N           140
# 1915662           2.14         1.0                  N           234
# 2001486           0.72         1.0                  N           141
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...
